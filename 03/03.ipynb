# %% [markdown]
# ## Задача. Обучите Neural Network от TensorFlow.

# %%
from google.colab import files
from tensorflow.keras import layers, models, utils
from IPython.display import display, Markdown
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as warn
import cv2

# для работы с графиками в интерактивном режиме
# %matplotlib inline

# устанавливаем точность чисел с плавающей точкой
# %precision %.4f

# отключаем предупреждения
warn.filterwarnings('ignore')

# %% [markdown]
# *Для этой задачи используем готовый датасет Fashion MNIST от TensorFlow*

# %%
# Загрузка датасета Fashion MNIST
(train_ds, test_ds), ds_info = tfds.load(
    'fashion_mnist',
    split=['train', 'test'],
    shuffle_files=True,
    as_supervised=True,
    with_info=True,
)
# Out:
# Downloading and preparing dataset 29.45 MiB (download: 29.45 MiB, generated: 36.42 MiB, total: 65.87 MiB) to /root/tensorflow_datasets/fashion_mnist/3.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/fashion_mnist/3.0.1.incomplete9KPIZ7/fashion_mnist-train.tfrecord*...:   0…
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/fashion_mnist/3.0.1.incomplete9KPIZ7/fashion_mnist-test.tfrecord*...:   0%…
# Dataset fashion_mnist downloaded and prepared to /root/tensorflow_datasets/fashion_mnist/3.0.1. Subsequent calls will reuse this data.

# %%
# Функция отображения изображений
def display_images(dataset, num_images=5):
    plt.figure(figsize=(10, 10))
    for i, (image, label) in enumerate(dataset.take(num_images)):
        plt.subplot(1, num_images, i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(image.numpy(), cmap=plt.cm.binary)
        plt.xlabel(ds_info.features['label'].int2str(label))
    plt.show()

# Количество изображений для отображения
num_images = 10

# Отображаем несколько изображений
display_images(train_ds, num_images)

# %%
# Функция нормализации
def normalize_img(image, label):
    return tf.cast(image, tf.float32) / 255.0, label

# Применение нормализации
train_ds = train_ds.map(normalize_img, num_parallel_calls=tf.data.experimental.AUTOTUNE).batch(32)
test_ds = test_ds.map(normalize_img, num_parallel_calls=tf.data.experimental.AUTOTUNE).batch(32)

# %%
# Создание модели
model = models.Sequential([
    # Сверточный слой, принимающий изображение размером 28x28 пикселей
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),
    # Второй сверточный слой
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),
    # Третий сверточный слой
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),
    # Переход от свёрточных слоёв к полносвязным слоям
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    # Выходной слой с 10 нейронами, соответствующими классам одежды
    layers.Dense(10, activation='softmax')
])

# Компиляция модели
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Обзор всех слоев
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  batch_normalization (Batch  (None, 26, 26, 32)        128
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 13, 13, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 13, 13, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  batch_normalization_1 (Bat  (None, 11, 11, 64)        256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 5, 5, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 128)         73856
#
#  batch_normalization_2 (Bat  (None, 3, 3, 128)         512
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 1, 1, 128)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 1, 1, 128)         0
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 128)               16512
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 111370 (435.04 KB)
# Trainable params: 110922 (433.29 KB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________

# %%
# Обучение модели
history = model.fit(train_ds, batch_size=32, epochs=20, validation_data=test_ds)
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 88s 46ms/step - loss: 0.6926 - accuracy: 0.7517 - val_loss: 0.4342 - val_accuracy: 0.8375
# Epoch 2/20
# 1875/1875 [==============================] - 79s 42ms/step - loss: 0.4758 - accuracy: 0.8290 - val_loss: 0.3783 - val_accuracy: 0.8564
# Epoch 3/20
# 1875/1875 [==============================] - 85s 46ms/step - loss: 0.4263 - accuracy: 0.8460 - val_loss: 0.3540 - val_accuracy: 0.8693
# Epoch 4/20
# 1875/1875 [==============================] - 78s 42ms/step - loss: 0.3984 - accuracy: 0.8557 - val_loss: 0.3424 - val_accuracy: 0.8717
# Epoch 5/20
# 1875/1875 [==============================] - 80s 43ms/step - loss: 0.3836 - accuracy: 0.8599 - val_loss: 0.3506 - val_accuracy: 0.8683
# Epoch 6/20
# 1875/1875 [==============================] - 79s 42ms/step - loss: 0.3657 - accuracy: 0.8679 - val_loss: 0.3286 - val_accuracy: 0.8763
# Epoch 7/20
# 1875/1875 [==============================] - 78s 42ms/step - loss: 0.3547 - accuracy: 0.8714 - val_loss: 0.3544 - val_accuracy: 0.8673
# Epoch 8/20
# 1875/1875 [==============================] - 80s 43ms/step - loss: 0.3425 - accuracy: 0.8769 - val_loss: 0.3150 - val_accuracy: 0.8826
# Epoch 9/20
# 1875/1875 [==============================] - 77s 41ms/step - loss: 0.3363 - accuracy: 0.8783 - val_loss: 0.3204 - val_accuracy: 0.8789
# Epoch 10/20
# 1875/1875 [==============================] - 81s 43ms/step - loss: 0.3285 - accuracy: 0.8806 - val_loss: 0.3362 - val_accuracy: 0.8797
# Epoch 11/20
# 1875/1875 [==============================] - 81s 43ms/step - loss: 0.3213 - accuracy: 0.8827 - val_loss: 0.3136 - val_accuracy: 0.8883
# Epoch 12/20
# 1875/1875 [==============================] - 82s 44ms/step - loss: 0.3160 - accuracy: 0.8850 - val_loss: 0.2905 - val_accuracy: 0.8941
# Epoch 13/20
# 1875/1875 [==============================] - 81s 43ms/step - loss: 0.3125 - accuracy: 0.8866 - val_loss: 0.2843 - val_accuracy: 0.8951
# Epoch 14/20
# 1875/1875 [==============================] - 79s 42ms/step - loss: 0.3091 - accuracy: 0.8866 - val_loss: 0.2879 - val_accuracy: 0.8919
# Epoch 15/20
# 1875/1875 [==============================] - 81s 43ms/step - loss: 0.3027 - accuracy: 0.8887 - val_loss: 0.2907 - val_accuracy: 0.8942
# Epoch 16/20
# 1875/1875 [==============================] - 79s 42ms/step - loss: 0.2967 - accuracy: 0.8911 - val_loss: 0.3033 - val_accuracy: 0.8857
# Epoch 17/20
# 1875/1875 [==============================] - 80s 42ms/step - loss: 0.2969 - accuracy: 0.8907 - val_loss: 0.2843 - val_accuracy: 0.8966
# Epoch 18/20
# 1875/1875 [==============================] - 79s 42ms/step - loss: 0.2926 - accuracy: 0.8926 - val_loss: 0.2805 - val_accuracy: 0.8968
# Epoch 19/20
# 1875/1875 [==============================] - 80s 43ms/step - loss: 0.2907 - accuracy: 0.8930 - val_loss: 0.2860 - val_accuracy: 0.8936
# Epoch 20/20
# 1875/1875 [==============================] - 81s 43ms/step - loss: 0.2876 - accuracy: 0.8942 - val_loss: 0.2691 - val_accuracy: 0.8995

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Точность модели')
plt.ylabel('точность')
plt.xlabel('количество эпох')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Потери модели')
plt.ylabel('Потери')
plt.xlabel('количество эпох')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
utils.plot_model(model)
